# %%
from sympy import symbols, sqrt, Derivative
import sympy as sp
x = symbols('x')

# %%
y = ((-6*10**-11)*x**4)-(0.00000004*x**3)+(0.0000096*x**2)-(0.0006*x)+0.016
y
# Out:
# -6.0e-11*x**4 - 4.0e-8*x**3 + 9.6e-6*x**2 - 0.0006*x + 0.016

# %%
nulpunt = sp.solve(y, x)
nulpunt
# Out:
# [-865.332847320067 + 0.e-19*I,
#  38.5856234533804 - 32.3667407015413*I,
#  38.5856234533804 + 32.3667407015413*I,
#  121.494933746639 + 0.e-19*I]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate x values
x = np.linspace(-10, 10, 100)

f = lambda x: ((-6*10**-11)*x**4)-(0.00000004*x**3)+(0.0000096*x**2)-(0.0006*x)+0.016

y = f(x)

# Plot the graph
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph of y = x')
plt.grid(True)
plt.show()
